# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook
from matplotlib.path import Path
from matplotlib.patches import PathPatch

# %%
def read_xyz_model_data(path2file, nx, ny, nz):
    """
    read in from xyz model data file
    """
    vd=[]
    with open(path2file) as fd:
        dlines = fd.readlines()
        for aline in dlines:
            dvalues = aline.split()
            #print (dvalues[-1])
            vd.append(float(dvalues[-1]))
            
    vdd = np.array(vd)
    #return np.reshape(vdd,(-1,ny))
    return np.reshape(vdd,(nx,ny,nz))

# %%
path2file = "/g/data/ha3/fxz547/travel_time_tomography/ModelData_Conversion/PnS_Inv_2degree/test1.xyz"
model_dat= read_xyz_model_data(path2file, 1,27,45)

# %%
print (model_dat.shape)
# Out:
# (1, 27, 45)

# %%
print(model_dat[0,:,:])
# Out:
# [[ 3.88430000e-01  3.34000005e-03 -1.15830000e-01 ...  1.59999996e-03
#    1.38999999e-03 -1.21000002e-03]
#  [ 7.94560020e-01  1.09330000e-01 -1.50180000e-01 ...  6.51999982e-03
#    6.92000007e-03 -1.59999996e-03]
#  [ 8.28279970e-01  2.59750010e-01  1.03100000e-01 ...  1.10499999e-02
#    4.42000013e-03  9.69999994e-04]
#  ...
#  [ 2.60199998e-02  2.32999995e-02  4.18800004e-02 ...  1.53000001e-02
#    4.81999991e-03 -3.56999994e-03]
#  [-4.01999988e-03  4.61000018e-03  2.10100003e-02 ...  1.52000005e-03
#   -3.75999999e-03 -2.14000000e-03]
#  [-1.54900001e-02  4.98000020e-03  4.78200018e-02 ... -1.18000002e-03
#   -6.98000006e-03 -6.09999988e-04]]

# %%
idepth=0

plt.clf()
plt.imshow(model_dat[idepth,:,:], interpolation='bilinear')
plt.show()

# %%
path2file = "/g/data/ha3/fxz547/travel_time_tomography/ModelData_Conversion/PnS_Inv_2degree/P-wave_it3.xyz"

model_dat= read_xyz_model_data(path2file, 22,27,45)

print (model_dat.shape)  # (nz, lat, long)

print(model_dat[0,:,:])
# Out:
# (22, 27, 45)
# [[ 1.75520000e-01 -7.11730000e-01 -5.59120000e-01 ... -8.68999958e-03
#    2.43000011e-03  6.57500029e-02]
#  [ 1.41106000e+00 -1.62999996e-03 -4.78500010e-01 ...  1.67999999e-03
#    5.07999994e-02  2.18440000e-01]
#  [ 1.65293000e+00  9.73100010e-01  2.11300000e-01 ... -7.57999998e-03
#    9.23999958e-03  7.56800026e-02]
#  ...
#  [ 5.38300015e-02  7.95300007e-02  2.09330010e-01 ...  1.93000003e-03
#   -7.99999980e-04 -1.16999994e-03]
#  [-1.40399998e-02  6.99999975e-04  6.26199991e-02 ...  3.64000001e-03
#    2.06999993e-03 -4.79999988e-04]
#  [-2.25399993e-02 -1.18899997e-02  2.43699998e-02 ... -3.94999981e-03
#   -6.20999979e-03  3.60000005e-04]]

# %%
def show(idepth):

    fig, ax = plt.subplots()

    ax.clear()

    im = ax.imshow(model_dat[idepth,:,:], interpolation='bilinear')

    plt.show()

# %%
show(0)
