# %% [markdown]
# # Federated-ASDF database

# %% [markdown]
# ## The Index SQLite3 database

# %%
import pandas as pd
import sqlite3

def get_netsta_pdf(dburl="/g/data/ha3/Passive/SHARED_DATA/Index/778837537aa72d892df7b0ba22320f537c1d8f6a.db"):
    """ Read sqlite table for network.station info into a pandas DataFrame
    """

    con = sqlite3.connect(dburl)
    
    # Read sqlite query results into a pandas DataFrame
    df = pd.read_sql_query("SELECT * from netsta", con)

    # Verify that result of SQL query is stored in the dataframe
    print("The size of the TABLE netsta=", df.size)
    
    print(df.head(5))

    con.close()
    
    return df

def get_netsta_rows(net,sta):
    filter1 = netsta_pdf["net"] == net 
    filter2 = netsta_pdf["sta"] == sta   #'ARMA' #'AXCOZ'

    a_pdf=netsta_pdf.loc[filter1 & filter2]

    print("Number of rows found in the TABLE netsta:", a_pdf.size)
    return a_pdf

# %%
netsta_pdf = get_netsta_pdf()

netcode ='AU' 
stacode ='ARMA' #'AXCOZ'

print("********* Query for the networ, station (%s,%s)"% (netcode,stacode))
df=get_netsta_rows(netcode,stacode)
print (df.head(5))
# Out:
# The size of the TABLE netsta= 15150
#    ds_id net   sta       lon      lat
# 0      0  AU   CTA  146.2540 -20.0885
# 1      0  AU  FITZ  125.6430 -18.1030
# 2      0  AU  KAKA  132.4396 -12.7115
# 3      0  AU  RKGY  116.9773 -34.6094
# 4      1  AU  AS03  133.9197 -23.6744
# ********* Query for the networ, station (AU,ARMA)
# Number of rows found 40
#      ds_id net   sta       lon      lat
# 25       3  AU  ARMA  151.6280 -30.4198
# 99       4  AU  ARMA  151.6280 -30.4198
# 225      5  AU  ARMA  151.6293 -30.4183
# 482      6  AU  ARMA  151.6293 -30.4183
# 802      7  AU  ARMA  151.6293 -30.4183

# %% [markdown]
# ## ASDF Archive Data (in HDF5 format)

# %%
import pyasdf

# %%
asdffile="/g/data/ha3/Passive/STRIPED_DATA/GA_PERM/2018-2019.h5"  # too large
# asdffile = "/g/data/ha3/GASeisDataArchive/DevSpace/2020.h5"

# %%
ds=pyasdf.ASDFDataSet(asdffile, mode="r")

# %%
# ds.validate()

# %%
print(ds.waveforms.list())
# Out:
# ['AK.BESE', 'AK.FYU', 'AK.JIS', 'AK.MESA', 'AK.NIKH', 'AK.SPIA', 'AK.TNA', 'AK.UNV', 'AT.AKUT', 'AT.CRAG', 'AT.OHAK', 'AT.SDPT', 'AT.SMY', 'AU.ARMA', 'AU.ARPS', 'AU.AS01', 'AU.AS02', 'AU.AS03', 'AU.AS04', 'AU.AS05', 'AU.AS06', 'AU.AS07', 'AU.AS08', 'AU.AS09', 'AU.AS10', 'AU.AS11', 'AU.AS12', 'AU.AS13', 'AU.AS14', 'AU.AS15', 'AU.AS16', 'AU.AS17', 'AU.AS19', 'AU.AS31', 'AU.AXCOZ', 'AU.BBOO', 'AU.BLDU', 'AU.BN2S', 'AU.BOXOZ', 'AU.BRAT', 'AU.BW1H', 'AU.BW2S', 'AU.CARL', 'AU.CATI', 'AU.CMSA', 'AU.CN1H', 'AU.CN2S', 'AU.CNB', 'AU.COEN', 'AU.CORO', 'AU.CTA', 'AU.DLN', 'AU.DPH', 'AU.DRS', 'AU.EIDS', 'AU.FITZ', 'AU.FORT', 'AU.GC1S', 'AU.GC2F', 'AU.GD1S', 'AU.GEXS', 'AU.GHSS', 'AU.GIRL', 'AU.GLAD', 'AU.GVL', 'AU.HTT', 'AU.INKA', 'AU.KDU', 'AU.KELC', 'AU.KLBR', 'AU.KMBL', 'AU.KNRA', 'AU.LCRK', 'AU.LHI', 'AU.LM01', 'AU.LM02', 'AU.LM03', 'AU.LM04', 'AU.LM05', 'AU.MABG', 'AU.MANU', 'AU.MAW', 'AU.MCQ', 'AU.MEEK', 'AU.MGBR', 'AU.MGCD', 'AU.MILA', 'AU.MLBS', 'AU.MOO', 'AU.MORW', 'AU.MTKN', 'AU.MTN', 'AU.MTSU', 'AU.MULG', 'AU.MUN', 'AU.NAPP', 'AU.NFK', 'AU.NIUE', 'AU.NTLH', 'AU.NTLS', 'AU.NTNOZ', 'AU.NWAO', 'AU.OKDL', 'AU.OOD', 'AU.PHB', 'AU.PSA00', 'AU.PSAA1', 'AU.PSAA2', 'AU.PSAA3', 'AU.PSAB1', 'AU.PSAB2', 'AU.PSAB3', 'AU.PSAC1', 'AU.PSAC2', 'AU.PSAC3', 'AU.PSAD1', 'AU.PSAD2', 'AU.PSAD3', 'AU.PTPS', 'AU.QIS', 'AU.QLP', 'AU.RABL', 'AU.RIV', 'AU.RK1H', 'AU.RK2S', 'AU.RKGY', 'AU.RMQ', 'AU.SDAN', 'AU.STKA', 'AU.SYDH', 'AU.SYDS', 'AU.TOO', 'AU.TV1H', 'AU.TV2S', 'AU.TW1H', 'AU.TWOA', 'AU.WB1', 'AU.WB10', 'AU.WB2', 'AU.WB3', 'AU.WB4', 'AU.WB5', 'AU.WB6', 'AU.WB7', 'AU.WB8', 'AU.WB9', 'AU.WC1', 'AU.WC2', 'AU.WC3', 'AU.WC4', 'AU.WHYH', 'AU.WOLH', 'AU.WR1', 'AU.WR10', 'AU.WR2', 'AU.WR3', 'AU.WR4', 'AU.WR5', 'AU.WR6', 'AU.WR7', 'AU.WR8', 'AU.WR9', 'AU.WRKA', 'AU.WTPK', 'AU.XMI', 'AU.XMIS', 'AU.YAPP', 'AU.YARR', 'AU.YNG', 'BW.RJOB', 'CN.BBB', 'CN.INK', 'CN.YKAW1', 'CU.GTBY', 'G.AIS', 'G.CAN', 'G.COYC', 'G.CRZF', 'G.DZM', 'G.FDF', 'G.FOMA', 'G.HDC', 'G.INU', 'G.MPG', 'G.NOUC', 'G.PAF', 'G.PEL', 'G.PPTF', 'G.RER', 'G.SPB', 'G.TAOE', 'G.TRIS', 'G.UNM', 'GE.BKB', 'GE.BKNI', 'GE.BNDI', 'GE.EIL', 'GE.FAKI', 'GE.GENI', 'GE.GSI', 'GE.HALK', 'GE.HMDM', 'GE.JAGI', 'GE.KAAM', 'GE.KBU', 'GE.LHMI', 'GE.LUWI', 'GE.MALK', 'GE.MMRI', 'GE.MNAI', 'GE.PMBI', 'GE.SANI', 'GE.SAUI', 'GE.SBV', 'GE.SMRI', 'GE.SNAA', 'GE.SOEI', 'GE.TNTI', 'GE.UGM', 'GE.VOI', 'GR.FUR', 'GR.WET', 'GT.CPUP', 'GT.DBIC', 'GT.LBTB', 'GT.PLCA', 'GT.VNDA', 'HK.HKPS', 'IA.AAI', 'IA.ALKI', 'IA.ATNI', 'IA.BASI', 'IA.BBKI', 'IA.BBSI', 'IA.BKSI', 'IA.BLJI', 'IA.BLSI', 'IA.BWJI', 'IA.BYJI', 'IA.CBJI', 'IA.CMJI', 'IA.CNJI', 'IA.CTJI', 'IA.DBJI', 'IA.DBNI', 'IA.DNP', 'IA.EDFI', 'IA.EGSI', 'IA.GMJI', 'IA.GRJI', 'IA.JCJI', 'IA.KASI', 'IA.KBKI', 'IA.KCSI', 'IA.KLI', 'IA.KMPI', 'IA.KMSI', 'IA.KPJI', 'IA.KRAI', 'IA.KRK', 'IA.KSI', 'IA.LASI', 'IA.LEM', 'IA.LHSI', 'IA.LRTI', 'IA.LWLI', 'IA.MKBI', 'IA.MLSI', 'IA.MMPI', 'IA.MNSI', 'IA.MPSI', 'IA.MTKI', 'IA.NGJI', 'IA.NLAI', 'IA.PBSI', 'IA.PDSI', 'IA.PKKI', 'IA.PMSI', 'IA.PPBI', 'IA.PPSI', 'IA.PWJI', 'IA.RAPI', 'IA.SBJI', 'IA.SBSI', 'IA.SDSI', 'IA.SGSI', 'IA.SIJI', 'IA.SISI', 'IA.SKJI', 'IA.SMKI', 'IA.SMSI', 'IA.STKI', 'IA.SWI', 'IA.SWJI', 'IA.TMSI', 'IA.TNG', 'IA.TPRI', 'IA.TRSI', 'IA.TTSI', 'IA.TWSI', 'IA.UBSI', 'IA.UWJI', 'IA.WBSI', 'IC.BJT', 'IC.HIA', 'IC.LSA', 'IC.MDJ', 'IC.QIZ', 'II.AAK', 'II.ABPO', 'II.ARU', 'II.ASCN', 'II.BFO', 'II.BORG', 'II.BRVK', 'II.CMLA', 'II.COCO', 'II.DGAR', 'II.EFI', 'II.ERM', 'II.ESK', 'II.FFC', 'II.HOPE', 'II.JTS', 'II.KAPI', 'II.KDAK', 'II.KIV', 'II.KURK', 'II.MBAR', 'II.MSEY', 'II.MSVF', 'II.NIL', 'II.NNA', 'II.OBN', 'II.PALK', 'II.PFO', 'II.RAYN', 'II.RPN', 'II.SHEL', 'II.SUR', 'II.TAU', 'II.UOSS', 'II.WRAB', 'IM.ATD', 'IM.BOSAB', 'IM.BR101', 'IM.BR102', 'IM.BR103', 'IM.BR104', 'IM.BR105', 'IM.BR106', 'IM.BR131', 'IM.BR231', 'IM.CM01', 'IM.CM02', 'IM.CM03', 'IM.CM04', 'IM.CM05', 'IM.CM06', 'IM.CM07', 'IM.CM08', 'IM.CM09', 'IM.CM10', 'IM.CM11', 'IM.CM12', 'IM.CM13', 'IM.CM15', 'IM.CM16', 'IM.CM17', 'IM.CM18', 'IM.CM31', 'IM.KMBO', 'IM. ...

# %%
for net_station in ds.waveforms.list():
    net,sta =net_station.split(".")
    print("********** network and station *************",net,sta)
    get_netsta_rows(net,sta)
    print(ds.waveforms[net_station])
# Out:
# ********** network and station ************* AK BESE
# Number of rows found 10
# Contents of the data set for station AK.BESE:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AK FYU
# Number of rows found 10
# Contents of the data set for station AK.FYU:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AK JIS
# Number of rows found 10
# Contents of the data set for station AK.JIS:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AK MESA
# Number of rows found 10
# Contents of the data set for station AK.MESA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AK NIKH
# Number of rows found 10
# Contents of the data set for station AK.NIKH:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AK SPIA
# Number of rows found 10
# Contents of the data set for station AK.SPIA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AK TNA
# Number of rows found 10
# Contents of the data set for station AK.TNA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AK UNV
# Number of rows found 10
# Contents of the data set for station AK.UNV:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AT AKUT
# Number of rows found 25
# Contents of the data set for station AT.AKUT:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AT CRAG
# Number of rows found 30
# Contents of the data set for station AT.CRAG:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AT OHAK
# Number of rows found 10
# Contents of the data set for station AT.OHAK:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AT SDPT
# Number of rows found 10
# Contents of the data set for station AT.SDPT:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AT SMY
# Number of rows found 30
# Contents of the data set for station AT.SMY:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU ARMA
# Number of rows found 40
# Contents of the data set for station AU.ARMA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU ARPS
# Number of rows found 45
# Contents of the data set for station AU.ARPS:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS01
# Number of rows found 35
# Contents of the data set for station AU.AS01:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS02
# Number of rows found 10
# Contents of the data set for station AU.AS02:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS03
# Number of rows found 25
# Contents of the data set for station AU.AS03:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS04
# Number of rows found 10
# Contents of the data set for station AU.AS04:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS05
# Number of rows found 10
# Contents of the data set for station AU.AS05:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS06
# Number of rows found 35
# Contents of the data set for station AU.AS06:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS07
# Number of rows found 35
# Contents of the data set for station AU.AS07:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS08
# Number of rows found 35
# Contents of the data set for station AU.AS08:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS09
# Number of rows found 10
# Contents of the data set for station AU.AS09:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS10
# Number of rows found 10
# Contents of the data set for station AU.AS10:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS11
# Number of rows found 30
# Contents of the data set for station AU.AS11:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS12
# Number of rows found 10
# Contents of the data set for station AU.AS12:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS13
# Number of rows found 10
# Contents of the data set for station AU.AS13:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS14
# Number of rows found 35
# Contents of the data set for station AU.AS14:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS15
# Number of rows found 10
# Contents of the data set for station AU.AS15:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS16
# Number of rows found 10
# Contents of the data set for station AU.AS16:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS17
# Number of rows found 10
# Contents of the data set for station AU.AS17:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS19
# Number of rows found 10
# Contents of the data set for station AU.AS19:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AS31
# Number of rows found 35
# Contents of the data set for station AU.AS31:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU AXCOZ
# Number of rows found 0
# Contents of the data set for station AU.AXCOZ:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU BBOO
# Number of rows found 40
# Contents of the data set for station AU.BBOO:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU BLDU
# Number of rows found 40
# Contents of the data set for station AU.BLDU:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU BN2S
# Number of rows found 25
# Contents of the data set for station AU.BN2S:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU BOXOZ
# Number of rows found 0
# Contents of the data set for station AU.BOXOZ:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU BRAT
# Number of rows found 20
# Contents of the data set for station AU.BRAT:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU BW1H
# Number of rows found 20
# Contents of the data set for station AU.BW1H:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU BW2S
# Number of rows found 20
# Contents of the data set for station AU.BW2S:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU CARL
# Number of rows found 25
# Contents of the data set for station AU.CARL:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU CATI
# Number of rows found 0
# Contents of the data set for station AU.CATI:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU CMSA
# Number of rows found 50
# Contents of the data set for station AU.CMSA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU CN1H
# Number of rows found 20
# Contents of the data set for station AU.CN1H:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU CN2S
# Number of rows found 20
# Contents of the data set for station AU.CN2S:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU CNB
# Number of rows found 45
# Contents of the data set for station AU.CNB:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU COEN
# Number of rows found 40
# Contents of the data set for station AU.COEN:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU CORO
# Number of rows found 30
# Contents of the data set for station AU.CORO:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU CTA
# Number of rows found 50
# Contents of the data set for station AU.CTA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU DLN
# Number of rows found 20
# Contents of the data set for station AU.DLN:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU DPH
# Number of rows found 25
# Contents of the data set for station AU.DPH:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU DRS
# Number of rows found 20
# Contents of the data set for station AU.DRS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU EIDS
# Number of rows found 40
# Contents of the data set for station AU.EIDS:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU FITZ
# Number of rows found 50
# Contents of the data set for station AU.FITZ:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU FORT
# Number of rows found 40
# Contents of the data set for station AU.FORT:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU GC1S
# Number of rows found 25
# Contents of the data set for station AU.GC1S:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU GC2F
# Number of rows found 25
# Contents of the data set for station AU.GC2F:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU GD1S
# Number of rows found 25
# Contents of the data set for station AU.GD1S:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU GEXS
# Number of rows found 20
# Contents of the data set for station AU.GEXS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU GHSS
# Number of rows found 25
# Contents of the data set for station AU.GHSS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU GIRL
# Number of rows found 40
# Contents of the data set for station AU.GIRL:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU GLAD
# Number of rows found 25
# Contents of the data set for station AU.GLAD:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU GVL
# Number of rows found 25
# Contents of the data set for station AU.GVL:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU HTT
# Number of rows found 30
# Contents of the data set for station AU.HTT:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU INKA
# Number of rows found 20
# Contents of the data set for station AU.INKA:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU KDU
# Number of rows found 30
# Contents of the data set for station AU.KDU:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU KELC
# Number of rows found 0
# Contents of the data set for station AU.KELC:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU KLBR
# Number of rows found 45
# Contents of the data set for station AU.KLBR:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU KMBL
# Number of rows found 40
# Contents of the data set for station AU.KMBL:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU KNRA
# Number of rows found 30
# Contents of the data set for station AU.KNRA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU LCRK
# Number of rows found 20
# Contents of the data set for station AU.LCRK:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU LHI
# Number of rows found 35
# Contents of the data set for station AU.LHI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU LM01
# Number of rows found 0
# Contents of the data set for station AU.LM01:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU LM02
# Number of rows found 0
# Contents of the data set for station AU.LM02:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU LM03
# Number of rows found 0
# Contents of the data set for station AU.LM03:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU LM04
# Number of rows found 0
# Contents of the data set for station AU.LM04:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU LM05
# Number of rows found 0
# Contents of the data set for station AU.LM05:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MABG
# Number of rows found 0
# Contents of the data set for station AU.MABG:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MANU
# Number of rows found 30
# Contents of the data set for station AU.MANU:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MAW
# Number of rows found 40
# Contents of the data set for station AU.MAW:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MCQ
# Number of rows found 40
# Contents of the data set for station AU.MCQ:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MEEK
# Number of rows found 45
# Contents of the data set for station AU.MEEK:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MGBR
# Number of rows found 0
# Contents of the data set for station AU.MGBR:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MGCD
# Number of rows found 40
# Contents of the data set for station AU.MGCD:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MILA
# Number of rows found 50
# Contents of the data set for station AU.MILA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MLBS
# Number of rows found 20
# Contents of the data set for station AU.MLBS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MOO
# Number of rows found 40
# Contents of the data set for station AU.MOO:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MORW
# Number of rows found 45
# Contents of the data set for station AU.MORW:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MTKN
# Number of rows found 25
# Contents of the data set for station AU.MTKN:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MTN
# Number of rows found 35
# Contents of the data set for station AU.MTN:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MTSU
# Number of rows found 40
# Contents of the data set for station AU.MTSU:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MULG
# Number of rows found 20
# Contents of the data set for station AU.MULG:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU MUN
# Number of rows found 45
# Contents of the data set for station AU.MUN:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU NAPP
# Number of rows found 25
# Contents of the data set for station AU.NAPP:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU NFK
# Number of rows found 30
# Contents of the data set for station AU.NFK:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU NIUE
# Number of rows found 35
# Contents of the data set for station AU.NIUE:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU NTLH
# Number of rows found 20
# Contents of the data set for station AU.NTLH:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU NTLS
# Number of rows found 25
# Contents of the data set for station AU.NTLS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU NTNOZ
# Number of rows found 0
# Contents of the data set for station AU.NTNOZ:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU NWAO
# Number of rows found 40
# Contents of the data set for station AU.NWAO:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU OKDL
# Number of rows found 0
# Contents of the data set for station AU.OKDL:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU OOD
# Number of rows found 20
# Contents of the data set for station AU.OOD:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PHB
# Number of rows found 0
# Contents of the data set for station AU.PHB:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PSA00
# Number of rows found 25
# Contents of the data set for station AU.PSA00:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PSAA1
# Number of rows found 25
# Contents of the data set for station AU.PSAA1:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PSAA2
# Number of rows found 25
# Contents of the data set for station AU.PSAA2:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PSAA3
# Number of rows found 25
# Contents of the data set for station AU.PSAA3:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PSAB1
# Number of rows found 25
# Contents of the data set for station AU.PSAB1:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PSAB2
# Number of rows found 25
# Contents of the data set for station AU.PSAB2:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PSAB3
# Number of rows found 25
# Contents of the data set for station AU.PSAB3:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PSAC1
# Number of rows found 25
# Contents of the data set for station AU.PSAC1:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PSAC2
# Number of rows found 25
# Contents of the data set for station AU.PSAC2:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PSAC3
# Number of rows found 25
# Contents of the data set for station AU.PSAC3:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PSAD1
# Number of rows found 25
# Contents of the data set for station AU.PSAD1:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PSAD2
# Number of rows found 25
# Contents of the data set for station AU.PSAD2:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PSAD3
# Number of rows found 25
# Contents of the data set for station AU.PSAD3:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU PTPS
# Number of rows found 25
# Contents of the data set for station AU.PTPS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU QIS
# Number of rows found 40
# Contents of the data set for station AU.QIS:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU QLP
# Number of rows found 45
# Contents of the data set for station AU.QLP:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU RABL
# Number of rows found 30
# Contents of the data set for station AU.RABL:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU RIV
# Number of rows found 40
# Contents of the data set for station AU.RIV:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU RK1H
# Number of rows found 25
# Contents of the data set for station AU.RK1H:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU RK2S
# Number of rows found 25
# Contents of the data set for station AU.RK2S:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU RKGY
# Number of rows found 55
# Contents of the data set for station AU.RKGY:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU RMQ
# Number of rows found 40
# Contents of the data set for station AU.RMQ:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU SDAN
# Number of rows found 0
# Contents of the data set for station AU.SDAN:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU STKA
# Number of rows found 35
# Contents of the data set for station AU.STKA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU SYDH
# Number of rows found 25
# Contents of the data set for station AU.SYDH:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU SYDS
# Number of rows found 25
# Contents of the data set for station AU.SYDS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU TOO
# Number of rows found 40
# Contents of the data set for station AU.TOO:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU TV1H
# Number of rows found 20
# Contents of the data set for station AU.TV1H:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU TV2S
# Number of rows found 20
# Contents of the data set for station AU.TV2S:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU TW1H
# Number of rows found 25
# Contents of the data set for station AU.TW1H:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU TWOA
# Number of rows found 25
# Contents of the data set for station AU.TWOA:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WB1
# Number of rows found 40
# Contents of the data set for station AU.WB1:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WB10
# Number of rows found 10
# Contents of the data set for station AU.WB10:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WB2
# Number of rows found 40
# Contents of the data set for station AU.WB2:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WB3
# Number of rows found 40
# Contents of the data set for station AU.WB3:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WB4
# Number of rows found 40
# Contents of the data set for station AU.WB4:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WB5
# Number of rows found 40
# Contents of the data set for station AU.WB5:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WB6
# Number of rows found 40
# Contents of the data set for station AU.WB6:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WB7
# Number of rows found 40
# Contents of the data set for station AU.WB7:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WB8
# Number of rows found 40
# Contents of the data set for station AU.WB8:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WB9
# Number of rows found 40
# Contents of the data set for station AU.WB9:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WC1
# Number of rows found 40
# Contents of the data set for station AU.WC1:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WC2
# Number of rows found 40
# Contents of the data set for station AU.WC2:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WC3
# Number of rows found 40
# Contents of the data set for station AU.WC3:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WC4
# Number of rows found 40
# Contents of the data set for station AU.WC4:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WHYH
# Number of rows found 25
# Contents of the data set for station AU.WHYH:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WOLH
# Number of rows found 25
# Contents of the data set for station AU.WOLH:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WR1
# Number of rows found 40
# Contents of the data set for station AU.WR1:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WR10
# Number of rows found 10
# Contents of the data set for station AU.WR10:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WR2
# Number of rows found 40
# Contents of the data set for station AU.WR2:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WR3
# Number of rows found 40
# Contents of the data set for station AU.WR3:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WR4
# Number of rows found 40
# Contents of the data set for station AU.WR4:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WR5
# Number of rows found 40
# Contents of the data set for station AU.WR5:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WR6
# Number of rows found 40
# Contents of the data set for station AU.WR6:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WR7
# Number of rows found 40
# Contents of the data set for station AU.WR7:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WR8
# Number of rows found 40
# Contents of the data set for station AU.WR8:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WR9
# Number of rows found 40
# Contents of the data set for station AU.WR9:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WRKA
# Number of rows found 30
# Contents of the data set for station AU.WRKA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU WTPK
# Number of rows found 0
# Contents of the data set for station AU.WTPK:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU XMI
# Number of rows found 30
# Contents of the data set for station AU.XMI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU XMIS
# Number of rows found 40
# Contents of the data set for station AU.XMIS:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU YAPP
# Number of rows found 0
# Contents of the data set for station AU.YAPP:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU YARR
# Number of rows found 0
# Contents of the data set for station AU.YARR:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* AU YNG
# Number of rows found 40
# Contents of the data set for station AU.YNG:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* BW RJOB
# Number of rows found 5
# Contents of the data set for station BW.RJOB:
#     - Has a StationXML file
#     - 0 Waveform Tag(s):
#
# ********** network and station ************* CN BBB
# Number of rows found 10
# Contents of the data set for station CN.BBB:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* CN INK
# Number of rows found 10
# Contents of the data set for station CN.INK:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* CN YKAW1
# Number of rows found 5
# Contents of the data set for station CN.YKAW1:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* CU GTBY
# Number of rows found 20
# Contents of the data set for station CU.GTBY:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G AIS
# Number of rows found 20
# Contents of the data set for station G.AIS:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G CAN
# Number of rows found 25
# Contents of the data set for station G.CAN:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G COYC
# Number of rows found 5
# Contents of the data set for station G.COYC:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G CRZF
# Number of rows found 30
# Contents of the data set for station G.CRZF:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G DZM
# Number of rows found 30
# Contents of the data set for station G.DZM:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G FDF
# Number of rows found 5
# Contents of the data set for station G.FDF:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G FOMA
# Number of rows found 25
# Contents of the data set for station G.FOMA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G HDC
# Number of rows found 5
# Contents of the data set for station G.HDC:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G INU
# Number of rows found 5
# Contents of the data set for station G.INU:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G MPG
# Number of rows found 15
# Contents of the data set for station G.MPG:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G NOUC
# Number of rows found 5
# Contents of the data set for station G.NOUC:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G PAF
# Number of rows found 30
# Contents of the data set for station G.PAF:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G PEL
# Number of rows found 5
# Contents of the data set for station G.PEL:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G PPTF
# Number of rows found 30
# Contents of the data set for station G.PPTF:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G RER
# Number of rows found 30
# Contents of the data set for station G.RER:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G SPB
# Number of rows found 5
# Contents of the data set for station G.SPB:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G TAOE
# Number of rows found 30
# Contents of the data set for station G.TAOE:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G TRIS
# Number of rows found 5
# Contents of the data set for station G.TRIS:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* G UNM
# Number of rows found 5
# Contents of the data set for station G.UNM:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE BKB
# Number of rows found 30
# Contents of the data set for station GE.BKB:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE BKNI
# Number of rows found 30
# Contents of the data set for station GE.BKNI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE BNDI
# Number of rows found 30
# Contents of the data set for station GE.BNDI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE EIL
# Number of rows found 30
# Contents of the data set for station GE.EIL:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE FAKI
# Number of rows found 30
# Contents of the data set for station GE.FAKI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE GENI
# Number of rows found 30
# Contents of the data set for station GE.GENI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE GSI
# Number of rows found 35
# Contents of the data set for station GE.GSI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE HALK
# Number of rows found 30
# Contents of the data set for station GE.HALK:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE HMDM
# Number of rows found 30
# Contents of the data set for station GE.HMDM:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE JAGI
# Number of rows found 30
# Contents of the data set for station GE.JAGI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE KAAM
# Number of rows found 30
# Contents of the data set for station GE.KAAM:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE KBU
# Number of rows found 15
# Contents of the data set for station GE.KBU:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE LHMI
# Number of rows found 30
# Contents of the data set for station GE.LHMI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE LUWI
# Number of rows found 30
# Contents of the data set for station GE.LUWI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE MALK
# Number of rows found 30
# Contents of the data set for station GE.MALK:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE MMRI
# Number of rows found 30
# Contents of the data set for station GE.MMRI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE MNAI
# Number of rows found 30
# Contents of the data set for station GE.MNAI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE PMBI
# Number of rows found 30
# Contents of the data set for station GE.PMBI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE SANI
# Number of rows found 30
# Contents of the data set for station GE.SANI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE SAUI
# Number of rows found 30
# Contents of the data set for station GE.SAUI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE SBV
# Number of rows found 30
# Contents of the data set for station GE.SBV:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE SMRI
# Number of rows found 30
# Contents of the data set for station GE.SMRI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE SNAA
# Number of rows found 30
# Contents of the data set for station GE.SNAA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE SOEI
# Number of rows found 30
# Contents of the data set for station GE.SOEI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE TNTI
# Number of rows found 30
# Contents of the data set for station GE.TNTI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE UGM
# Number of rows found 30
# Contents of the data set for station GE.UGM:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GE VOI
# Number of rows found 30
# Contents of the data set for station GE.VOI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GR FUR
# Number of rows found 5
# Contents of the data set for station GR.FUR:
#     - Has a StationXML file
#     - 0 Waveform Tag(s):
#
# ********** network and station ************* GR WET
# Number of rows found 5
# Contents of the data set for station GR.WET:
#     - Has a StationXML file
#     - 0 Waveform Tag(s):
#
# ********** network and station ************* GT CPUP
# Number of rows found 20
# Contents of the data set for station GT.CPUP:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GT DBIC
# Number of rows found 30
# Contents of the data set for station GT.DBIC:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GT LBTB
# Number of rows found 30
# Contents of the data set for station GT.LBTB:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GT PLCA
# Number of rows found 20
# Contents of the data set for station GT.PLCA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* GT VNDA
# Number of rows found 25
# Contents of the data set for station GT.VNDA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* HK HKPS
# Number of rows found 30
# Contents of the data set for station HK.HKPS:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA AAI
# Number of rows found 5
# Contents of the data set for station IA.AAI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA ALKI
# Number of rows found 0
# Contents of the data set for station IA.ALKI:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA ATNI
# Number of rows found 0
# Contents of the data set for station IA.ATNI:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA BASI
# Number of rows found 5
# Contents of the data set for station IA.BASI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA BBKI
# Number of rows found 5
# Contents of the data set for station IA.BBKI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA BBSI
# Number of rows found 5
# Contents of the data set for station IA.BBSI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA BKSI
# Number of rows found 5
# Contents of the data set for station IA.BKSI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA BLJI
# Number of rows found 5
# Contents of the data set for station IA.BLJI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA BLSI
# Number of rows found 5
# Contents of the data set for station IA.BLSI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA BWJI
# Number of rows found 5
# Contents of the data set for station IA.BWJI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA BYJI
# Number of rows found 5
# Contents of the data set for station IA.BYJI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA CBJI
# Number of rows found 0
# Contents of the data set for station IA.CBJI:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA CMJI
# Number of rows found 5
# Contents of the data set for station IA.CMJI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA CNJI
# Number of rows found 5
# Contents of the data set for station IA.CNJI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA CTJI
# Number of rows found 0
# Contents of the data set for station IA.CTJI:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IA DBJI
# ...
# Number of rows found 30
# Contents of the data set for station IU.SJG:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IU SLBS
# Number of rows found 30
# Contents of the data set for station IU.SLBS:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IU SNZO
# Number of rows found 35
# Contents of the data set for station IU.SNZO:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IU SSPA
# Number of rows found 30
# Contents of the data set for station IU.SSPA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IU TARA
# Number of rows found 30
# Contents of the data set for station IU.TARA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IU TATO
# Number of rows found 30
# Contents of the data set for station IU.TATO:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IU TEIG
# Number of rows found 30
# Contents of the data set for station IU.TEIG:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IU TRQA
# Number of rows found 30
# Contents of the data set for station IU.TRQA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IU ULN
# Number of rows found 30
# Contents of the data set for station IU.ULN:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IU WAKE
# Number of rows found 30
# Contents of the data set for station IU.WAKE:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IU XMAS
# Number of rows found 30
# Contents of the data set for station IU.XMAS:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* IU YSS
# Number of rows found 30
# Contents of the data set for station IU.YSS:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* JP JNU
# Number of rows found 5
# Contents of the data set for station JP.JNU:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* JP JOW
# Number of rows found 5
# Contents of the data set for station JP.JOW:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* JP YOJ
# Number of rows found 5
# Contents of the data set for station JP.YOJ:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* KZ ABKAR
# Number of rows found 30
# Contents of the data set for station KZ.ABKAR:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* KZ MKAR
# Number of rows found 30
# Contents of the data set for station KZ.MKAR:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* MN WDD
# Number of rows found 25
# Contents of the data set for station MN.WDD:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* MS BTDF
# Number of rows found 10
# Contents of the data set for station MS.BTDF:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* MY KKM
# Number of rows found 35
# Contents of the data set for station MY.KKM:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* MY KSM
# Number of rows found 35
# Contents of the data set for station MY.KSM:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* MY KUM
# Number of rows found 35
# Contents of the data set for station MY.KUM:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* NZ APZ
# Number of rows found 35
# Contents of the data set for station NZ.APZ:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* NZ CTZ
# Number of rows found 20
# Contents of the data set for station NZ.CTZ:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* NZ DCZ
# Number of rows found 35
# Contents of the data set for station NZ.DCZ:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* NZ ODZ
# Number of rows found 35
# Contents of the data set for station NZ.ODZ:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* NZ OUZ
# Number of rows found 35
# Contents of the data set for station NZ.OUZ:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* ON ALF01
# Number of rows found 5
# Contents of the data set for station ON.ALF01:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* ON GUA01
# Number of rows found 0
# Contents of the data set for station ON.GUA01:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* PL OJC
# Number of rows found 20
# Contents of the data set for station PL.OJC:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* PS ISG
# Number of rows found 0
# Contents of the data set for station PS.ISG:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* PS JAY
# Number of rows found 0
# Contents of the data set for station PS.JAY:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* PS PATS
# Number of rows found 35
# Contents of the data set for station PS.PATS:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* PS PSI
# Number of rows found 35
# Contents of the data set for station PS.PSI:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUALB
# Number of rows found 15
# Contents of the data set for station S.AUALB:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUALC
# Number of rows found 5
# Contents of the data set for station S.AUALC:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUAYR
# Number of rows found 15
# Contents of the data set for station S.AUAYR:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUBRN
# Number of rows found 5
# Contents of the data set for station S.AUBRN:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUBSH
# Number of rows found 15
# Contents of the data set for station S.AUBSH:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUBUS
# Number of rows found 15
# Contents of the data set for station S.AUBUS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUCAS
# Number of rows found 15
# Contents of the data set for station S.AUCAS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUCSH
# Number of rows found 15
# Contents of the data set for station S.AUCSH:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUDAR
# Number of rows found 15
# Contents of the data set for station S.AUDAR:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUDCS
# Number of rows found 15
# Contents of the data set for station S.AUDCS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUDHS
# Number of rows found 15
# Contents of the data set for station S.AUDHS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUHAR
# Number of rows found 15
# Contents of the data set for station S.AUHAR:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUHPC
# Number of rows found 15
# Contents of the data set for station S.AUHPC:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUJCS
# Number of rows found 20
# Contents of the data set for station S.AUJCS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUKAL
# Number of rows found 15
# Contents of the data set for station S.AUKAL:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUKHS
# Number of rows found 15
# Contents of the data set for station S.AUKHS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUKSC
# Number of rows found 15
# Contents of the data set for station S.AUKSC:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUKUL
# Number of rows found 0
# Contents of the data set for station S.AUKUL:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AULHS
# Number of rows found 15
# Contents of the data set for station S.AULHS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AULRC
# Number of rows found 15
# Contents of the data set for station S.AULRC:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUMAG
# Number of rows found 15
# Contents of the data set for station S.AUMAG:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUMAR
# Number of rows found 15
# Contents of the data set for station S.AUMAR:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUMAZ
# Number of rows found 15
# Contents of the data set for station S.AUMAZ:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUMBR
# Number of rows found 10
# Contents of the data set for station S.AUMBR:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUMHS
# Number of rows found 15
# Contents of the data set for station S.AUMHS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUMTC
# Number of rows found 15
# Contents of the data set for station S.AUMTC:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUMTS
# Number of rows found 20
# Contents of the data set for station S.AUMTS:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUNHS
# Number of rows found 15
# Contents of the data set for station S.AUNHS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUNRC
# Number of rows found 15
# Contents of the data set for station S.AUNRC:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUPHS
# Number of rows found 15
# Contents of the data set for station S.AUPHS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUPKL
# Number of rows found 0
# Contents of the data set for station S.AUPKL:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AURSC
# Number of rows found 15
# Contents of the data set for station S.AURSC:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUSIS
# Number of rows found 15
# Contents of the data set for station S.AUSIS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUSMG
# Number of rows found 15
# Contents of the data set for station S.AUSMG:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUSSC
# Number of rows found 15
# Contents of the data set for station S.AUSSC:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUTAR
# Number of rows found 15
# Contents of the data set for station S.AUTAR:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUTKS
# Number of rows found 15
# Contents of the data set for station S.AUTKS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUTOO
# Number of rows found 15
# Contents of the data set for station S.AUTOO:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUUHS
# Number of rows found 15
# Contents of the data set for station S.AUUHS:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* S AUWSH
# Number of rows found 15
# Contents of the data set for station S.AUWSH:
#     - Has no StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* TW YHNB
# Number of rows found 30
# Contents of the data set for station TW.YHNB:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* US BOZ
# Number of rows found 10
# Contents of the data set for station US.BOZ:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* US EGMT
# Number of rows found 10
# Contents of the data set for station US.EGMT:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* US HAWA
# Number of rows found 10
# Contents of the data set for station US.HAWA:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* US KVTX
# Number of rows found 10
# Contents of the data set for station US.KVTX:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* US OGNE
# Number of rows found 10
# Contents of the data set for station US.OGNE:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording
# ********** network and station ************* US WMOK
# Number of rows found 10
# Contents of the data set for station US.WMOK:
#     - Has a StationXML file
#     - 1 Waveform Tag(s):
#         raw_recording

# %%
#sta1= ds.waveforms['AU.ARMA']  # has a station xml, has waveforms
# sta1= ds.waveforms['AU.AXCOZ'] # has NO stationXML, has waveforms
# sta1= ds.waveforms['S1.AUTKS']

sta1= ds.waveforms['AU.STKA']

# %%
type(sta1)
# Out:
# pyasdf.utils.WaveformAccessor

# %%
sta1.get_waveform_tags()
# Out:
# ['raw_recording']

# %%
print (len(sta1.list()))
print(sta1.list()[0])
print(sta1.list()[-1])  # This will be StationXML IF it exists
# Out:
# 3070
# AU.STKA..BHE__2018-01-01T00:00:00__2018-01-01T23:59:59__raw_recording
# StationXML

# %%
sta1.list()[-2:]
# Out:
# ['AU.STKA..BHZ__2018-12-31T00:00:01__2018-12-31T23:59:59__raw_recording',
#  'StationXML']

# %%
keystr=sta1.list()[0]
#astream = sta1['AU.ARMA..BHN__2020-01-06T08:42:51__2020-01-06T08:43:15__raw_recording']
astream = sta1[keystr]

# %%
astream.plot()   # ?? Why always 2 identical figures?

# %%
print(astream)
# Out:
# 1 Trace(s) in Stream:
# AU.STKA..BHE | 2018-01-01T00:00:00.000000Z - 2018-01-01T23:59:59.975000Z | 40.0 Hz, 3456000 samples

# %%
astream[0].plot()

# %%
sta1.StationXML   # if Has no StationXML, then error come out AttributeError: 'WaveformAccessor' object has no attribute 'StationXML'
# Out:
# Inventory created at 2019-05-04T14:17:58.000000Z
# 	Created by: None
# 		    None
# 	Sending institution: SeisComP3 (NA)
# 	Contains:
# 		Networks (1):
# 			AU
# 		Stations (1):
# 			AU.STKA (AU-STKA)
# 		Channels (2):
# 			AU.STKA..BHZ (2x)

# %%
sta1.StationXML.write("a_station.xml", format="STATIONXML")

# %%
# !ls
# Out:
# 'ASDF and Federated-ASDF.ipynb'   au_arma.xml			  __init__.py
#  a_station.xml			  get_waveforms_from_fedasdf.py   jup.log
