# %% [markdown]
# # Obspy handling waveform data
#
# Ref: cig_all_hands_2016_obspy_and_python_tutorial/ObsPy/03_waveform_data.ipynb

# %%
# %matplotlib inline

import matplotlib.pylab as plt
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = 12, 8

# %% [markdown]
# <img src="cig_all_hands_2016_obspy_and_python_tutorial/ObsPy/images/Stream_Trace.svg" width=90%>
#
# * read waveform data is returned as a **`Stream`** object.

# %%
datafile = "/Datasets/tmp_demult_mseed/1.0.AU.WB8.mseed"

from obspy import read
st = read(datafile, format="mseed")
print(st)
# Out:
# 1439 Trace(s) in Stream:
#
# AU.WB8..BHZ | 2019-09-30T00:00:00.850000Z - 2019-09-30T00:00:12.000000Z | 40.0 Hz, 447 samples
# ...
# (1437 other traces)
# ...
# AU.WB8..BHZ | 2019-09-30T11:14:20.000000Z - 2019-09-30T11:14:34.375000Z | 40.0 Hz, 576 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]

# %%
for tr in st:
    print(tr.id)
# Out:
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ
# AU.WB8..BHZ

# %% [markdown]
# - UNIX wildcards can be used to read multiple files simultaneously
# - automatic file format detection, no need to worry about file formats
#
#   - currently supported: **mseed, sac, segy, seg2, gse1/2, seisan, sh, datamark, css, wav, y, Q, kinemetrics Evt, K-NET & KiK-net data, pdas (keeps growing...)**
#   - more file formats are included whenever a basic reading routine is provided (or e.g. sufficient documentation on data compression etc.)
#   - custom user-specific file formats can be added (through plugin) to filetype autodiscovery in local ObsPy installation by user

# %%
# from obspy import read
# st = read("./data/waveform_*")
# print(st)

# %% [markdown]
# - for MiniSEED files, only reading short portions of files without all of the file getting read into memory is supported (saves time and memory when working on large collections of big files)

# %%
t= UTCDateTime("2019-09-30T01:54:40.000000Z")
st = read(datafile, starttime=t , endtime=t + 1 * 60)
print(st)
# Out:
# 4 Trace(s) in Stream:
# AU.WB8..BHZ | 2019-09-30T01:54:40.000000Z - 2019-09-30T01:54:52.600000Z | 40.0 Hz, 505 samples
# AU.WB8..BHZ | 2019-09-30T01:54:40.000000Z - 2019-09-30T01:54:52.600000Z | 40.0 Hz, 505 samples
# AU.WB8..BHZ | 2019-09-30T01:55:10.000000Z - 2019-09-30T01:55:34.925000Z | 40.0 Hz, 998 samples
# AU.WB8..BHZ | 2019-09-30T01:55:30.000000Z - 2019-09-30T01:55:40.000000Z | 40.0 Hz, 401 samples

# %% [markdown]
# #### The Stream Object
#
#  - A Stream object is a collection of Trace objects

# %%
print(type(st))
# Out:
# <class 'obspy.core.stream.Stream'>

# %%
print(st.traces)
# Out:
# [<obspy.core.trace.Trace object at 0x7fd4101fc8d0>, <obspy.core.trace.Trace object at 0x7fd4101fc358>]

# %%
print(st[0])
# Out:
# AU.WB8..BHZ | 2019-09-30T01:54:40.000000Z - 2019-09-30T01:54:52.600000Z | 40.0 Hz, 505 samples

# %%
st[0].stats
# Out:
#          network: AU
#          station: WB8
#         location:
#          channel: BHZ
#        starttime: 2019-09-30T01:54:40.000000Z
#          endtime: 2019-09-30T01:54:52.600000Z
#    sampling_rate: 40.0
#            delta: 0.025
#             npts: 505
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 1, 'encoding': 'STEIM2', 'byteorder': '>', 'record_length': 4096, 'filesize': 5898240})
#       processing: ['ObsPy 1.1.0: trim(endtime=None::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2019, 9, 30, 1, 54, 40))', 'ObsPy 1.1.0: trim(endtime=UTCDateTime(2019, 9, 30, 1, 55, 40)::fill_value=None::nearest_sample=True::pad=False::starttime=None)']

# %%
st[1].stats
# Out:
#          network: AU
#          station: WB8
#         location:
#          channel: BHZ
#        starttime: 2019-09-30T01:54:40.000000Z
#          endtime: 2019-09-30T01:54:52.600000Z
#    sampling_rate: 40.0
#            delta: 0.025
#             npts: 505
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 1, 'encoding': 'STEIM2', 'byteorder': '>', 'record_length': 4096, 'filesize': 5898240})
#       processing: ['ObsPy 1.1.0: trim(endtime=None::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2019, 9, 30, 1, 54, 40))', 'ObsPy 1.1.0: trim(endtime=UTCDateTime(2019, 9, 30, 1, 55, 40)::fill_value=None::nearest_sample=True::pad=False::starttime=None)']

# %% [markdown]
# - More traces can be assembled using **`+`** operator (or using the `.append()` and `.extend()` methods)

# %% [markdown]
#  - Stream is useful for applying the same processing to a larger number of different waveforms or to group Traces for processing (e.g. three components of one station in one Stream)

# %% [markdown]
# #### The Trace Object
#
# - a Trace object is a single, contiguous waveform data block (i.e. regularly spaced time series, no gaps)
# - a Trace object contains a limited amount of metadata in a dictionary-like object (as **`Trace.stats`**) that fully describes the time series by specifying..
#   * recording location/instrument (network, station, location and channel code)
#   * start time
#   * sampling rate

# %% [markdown]
# - For custom applications it is sometimes necessary to directly manipulate the metadata of a Trace.
# - The metadata of the Trace will **stay consistent**, as all values are derived from the starttime, the data and the sampling rate and are **updated automatically**

# %%
tr=st[0]

# %%
print(tr.stats.delta, "|", tr.stats.endtime)
# Out:
# 0.025 | 2019-09-30T01:54:52.600000Z

# %%
tr.stats.sampling_rate = 5.0
print(tr.stats.delta, "|", tr.stats.endtime)
# Out:
# 0.2 | 2019-09-30T01:56:20.800000Z

# %%
print(tr.stats.npts)
# Out:
# 505

# %%
tr.data = tr.data[:200]
print(tr.stats.npts, "|", tr.stats.endtime)
# Out:
# 200 | 2019-09-30T01:55:19.800000Z

# %% [markdown]
# - convenience methods make basic manipulations simple

# %%
#tr = read("./data/waveform_PFO.mseed")[0]
tr.plot()

# %%
st[1].plot()

# %%
st[0].plot()

# %%
tr=st[0]
print(tr)
tr.resample(sampling_rate=100.0)
print(tr)
# Out:
# AU.WB8..BHZ | 2019-09-30T01:54:40.000000Z - 2019-09-30T01:55:19.800000Z | 5.0 Hz, 200 samples
# AU.WB8..BHZ | 2019-09-30T01:54:40.000000Z - 2019-09-30T01:55:19.990000Z | 100.0 Hz, 4000 samples

# %%
print(tr)
tr.trim(tr.stats.starttime + 0 * 60, tr.stats.starttime + 0.5 * 60)
print(tr)
tr.plot()
# Out:
# AU.WB8..BHZ | 2019-09-30T01:54:40.000000Z - 2019-09-30T01:55:19.990000Z | 100.0 Hz, 4000 samples
# AU.WB8..BHZ | 2019-09-30T01:54:40.000000Z - 2019-09-30T01:55:10.000000Z | 100.0 Hz, 3001 samples

# %%
tr.detrend("linear")
tr.taper(max_percentage=0.05, type='cosine')
tr.filter("lowpass", freq=0.1)
tr.plot()
# Out:
# /home/fzhang/Py3Venvs/hiperseis/lib/python3.6/site-packages/obspy/core/trace.py:2111: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(self.data.dtype, float):

# %%
# try tr.<Tab> for other methods defined for Trace
tr.detrend?

# %% [markdown]
# - Raw data available as a [**`numpy.ndarray`**](http://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.html) (as **`Trace.data`**)

# %%
print(tr.data[:20])
# Out:
# [ 0.00000000e+00 -4.47613408e-13 -5.15388411e-12 -2.99732198e-11
#  -1.18895640e-10 -3.65678777e-10 -9.37091276e-10 -2.09375237e-09
#  -4.20505178e-09 -7.75514437e-09 -1.33375267e-08 -2.16362096e-08
#  -3.33919946e-08 -4.93528332e-08 -7.02076951e-08 -9.65037802e-08
#  -1.28547285e-07 -1.66288262e-07 -2.09190398e-07 -2.56086772e-07]

# %% [markdown]
# - Data can be directly modified e.g. ..
#
# ..by doing arithmetic operations (fast, handled in C by NumPy)

# %%
print(tr.data ** 2 + 0.5)
# Out:
# [5.00000000e-01 5.00000000e-01 5.00000000e-01 ... 8.74901784e+03
#  8.58507300e+03 8.42236066e+03]

# %% [markdown]
# ..by using [**`numpy.ndarray`** builtin methods](http://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.html) (also done in C by NumPy)

# %%
print(tr.data.max())
print(tr.data.mean())
print(tr.data.ptp())
# try tr.data.<Tab> for a list of numpy methods defined on ndarray
# Out:
# 232.5109854821655
# 22.243739048144565
# 386.8422772568265

# %% [markdown]
# ..by using **`numpy`** functions (also done in C by NumPy)

# %%
import numpy as np
print(np.abs(tr.data))
# you can try np.<Tab> but there is a lot in there
# try np.a<Tab>
# Out:
# [0.00000000e+00 4.47613408e-13 5.15388411e-12 ... 9.35335119e+01
#  9.26529708e+01 9.17706961e+01]

# %% [markdown]
# ..by feeding pointers to existing C/Fortran routines from inside Python!
#
# This is done internally in several places, e.g. for cross correlations, beamforming or in third-party filetype libraries like e.g. libmseed.
#
# - Trace objects can also be manually generated with data in a [**`numpy.ndarray`**](http://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.html) (e.g. when needing to parse waveforms from non-standard ascii files)

# %%
from obspy import Trace

x = np.random.randint(-100, 100, 500)
tr = Trace(data=x)
tr.stats.station = "XYZ"
tr.stats.starttime = UTCDateTime()

tr.plot()

# %% [markdown]
# - Stream objects can be assembled from manually generated Traces

# %%
from obspy import Stream

tr2 = Trace(data=np.random.randint(-300, 100, 1000))
tr2.stats.starttime = UTCDateTime()
tr2.stats.sampling_rate = 10.0
st = Stream([tr, tr2])

st.plot()

# %% [markdown]
# #### Builtin methods defined on **`Stream`** / **`Trace`**
#
# - Most methods that work on a Trace object also work on a Stream object. They are simply executed for every trace. [See ObsPy documentation for an overview of available methods](http://docs.obspy.org/packages/autogen/obspy.core.stream.Stream.html) (or try **`st.<Tab>`**).
#  - **`st.filter()`** - Filter all attached traces.
#  - **`st.trim()`** - Cut all traces.
#  - **`st.resample()`** / **`st.decimate()`** - Change the sampling rate.
#  - **`st.trigger()`** - Run triggering algorithms.
#  - **`st.plot()`** / **`st.spectrogram()`** - Visualize the data.
#  - **`st.attach_response()`**/**`st.remove_response()`**, **`st.simulate()`** - Instrument correction
#  - **`st.merge()`**, **`st.normalize()`**, **`st.detrend()`**, **`st.taper()`**, ...
# - A **`Stream`** object can also be exported to many formats, so ObsPy can be used to convert between different file formats.

# %%
st = read("./data/waveform_*.sac")
st.write("output_file.mseed", format="MSEED")
# !ls -l output_file*
# Out:
# -rw-r--r-- 1 fzhang fzhang 737280 Jun  8 19:26 output_file.mseed

# %% [markdown]
# <img src="images/Stream_Trace.svg" width=90%>

# %% [markdown]
# #### Trace Exercises
#  - Make an **`numpy.ndarray`** with zeros and (e.g. use **`numpy.zeros()`**) and put an ideal pulse somewhere in it
#  - initialize a **`Trace`** object with your data array
#  - Fill in some station information (e.g. network, station, ..)
#  - Print trace summary and plot the trace
#  - Change the sampling rate to 20 Hz
#  - Change the starttime of the trace to the start time of this session
#  - Print the trace summary and plot the trace again

# %% [markdown]
# - Use **`tr.filter(...)`** and apply a lowpass filter with a corner frequency of 1 Hertz.
# - Display the preview plot, there are a few seconds of zeros that we can cut off.

# %% [markdown]
# - Use **`tr.trim(...)`** to remove some of the zeros at start and at the end
# - show the preview plot again

# %% [markdown]
# - Scale up the amplitudes of the trace by a factor of 500
# - Add standard normal gaussian noise to the trace (use [**`np.random.randn()`**](http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html))
# - Display the preview plot again

# %% [markdown]
# #### Stream Exercises
#
# - Read all Tohoku example earthquake data into a stream object ("./data/waveform\_\*")
# - Print the stream summary

# %% [markdown]
# - Use **`st.select()`** to only keep traces of station BFO in the stream. Show the preview plot.

# %% [markdown]
# - trim the data to a 10 minute time window around the first arrival (just roughly looking at the preview plot)
# - display the preview plot and spectrograms for the stream (with logarithmic frequency scale, use `wlen=50` for the spectrogram plot)

# %% [markdown]
# - remove the linear trend from the data, apply a tapering and a lowpass at 0.1 Hertz
# - show the preview plot again
